# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.19.5 in /home/vscode/.local/lib/python3.11/site-packages (from scikit-learn) (2.1.0)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.9 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 45.3 MB/s eta 0:00:00:00:010:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 8.5 MB/s eta 0:00:00:00:01
# Downloading scipy-1.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 30.1 MB/s eta 0:00:00:00:0100:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.1 scipy-1.14.1 threadpoolctl-3.5.0
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in /home/vscode/.local/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: altair<6,>=4.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: packaging<25,>=20 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (5.28.0)
# Requirement already satisfied: pyarrow>=7.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (13.8.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (3.1.41)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /home/vscode/.local/lib/python3.11/site-packages (from streamlit->-r requirements.txt (line 1)) (4.0.2)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/vscode/.local/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: narwhals>=1.5.2 in /home/vscode/.local/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/vscode/.local/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/vscode/.local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 1)) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv('salaryData.csv')

df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.shape
# Out:
# (375, 6)

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Director of Marketing             12
# Director of Operations            11
# Senior Business Analyst           10
# Senior Marketing Manager           9
# Senior Marketing Analyst           9
#                                   ..
# Junior Social Media Specialist     1
# Junior Operations Coordinator      1
# Senior HR Specialist               1
# Director of HR                     1
# Junior Financial Advisor           1
# Name: count, Length: 174, dtype: int64

# %%
df['Education Level'].value_counts()
# Out:
# Education Level
# Bachelor's    224
# Master's       98
# PhD            51
# Name: count, dtype: int64

# %%
df_edited = df.groupby('Job Title').filter(lambda x : len(x)>4)
df_edited.info()
df_edited['Job Title'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147 entries, 47 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  147 non-null    float64
#  1   Gender               147 non-null    object
#  2   Education Level      147 non-null    object
#  3   Job Title            147 non-null    object
#  4   Years of Experience  147 non-null    float64
#  5   Salary               147 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 8.0+ KB
# Job Title
# Director of Marketing                    12
# Director of Operations                   11
# Senior Business Analyst                  10
# Senior Marketing Manager                  9
# Senior Marketing Analyst                  9
# Junior Business Analyst                   8
# Senior Project Manager                    7
# Senior Data Scientist                     7
# Senior Financial Analyst                  7
# Junior Business Development Associate     7
# Junior Financial Analyst                  7
# Senior Software Engineer                  6
# Senior Product Manager                    6
# Junior Marketing Coordinator              6
# Senior Project Coordinator                5
# Junior Operations Analyst                 5
# Junior Marketing Specialist               5
# Senior Product Designer                   5
# Junior Project Manager                    5
# Senior Operations Manager                 5
# Senior Financial Manager                  5
# Name: count, dtype: int64

# %%
df_edited['Job Title'] = df_edited['Job Title'].astype('category')

# %%
df_edited['Job Title Encoded'] = df_edited['Job Title'].cat.codes
df_edited.head()
# Out:
#      Age  Gender Education Level                 Job Title  \
# 47  45.0  Female        Master's     Director of Marketing
# 60  51.0  Female        Master's    Director of Operations
# 63  47.0    Male             PhD     Senior Data Scientist
# 69  49.0  Female        Master's  Senior Financial Analyst
# 77  32.0    Male        Master's  Senior Software Engineer
#
#     Years of Experience    Salary  Job Title Encoded
# 47                 16.0  180000.0                  0
# 60                 23.0  170000.0                  1
# 63                 21.0  180000.0                 10
# 69                 18.0  150000.0                 11
# 77                  6.0  100000.0                 20

# %%
df_edited.dtypes
# Out:
# Age                     float64
# Gender                   object
# Education Level          object
# Job Title              category
# Years of Experience     float64
# Salary                  float64
# Job Title Encoded          int8
# dtype: object

# %%
df_edited['Education Level'] = df_edited['Education Level'].astype('category')

# %%
df_edited.dtypes
# Out:
# Age                     float64
# Gender                   object
# Education Level        category
# Job Title              category
# Years of Experience     float64
# Salary                  float64
# Job Title Encoded          int8
# dtype: object

# %%
df_edited['Education Level Encoded'] = df_edited['Education Level'].cat.codes
df_edited.head()
# Out:
#      Age  Gender Education Level                 Job Title  \
# 47  45.0  Female        Master's     Director of Marketing
# 60  51.0  Female        Master's    Director of Operations
# 63  47.0    Male             PhD     Senior Data Scientist
# 69  49.0  Female        Master's  Senior Financial Analyst
# 77  32.0    Male        Master's  Senior Software Engineer
#
#     Years of Experience    Salary  Job Title Encoded  Education Level Encoded
# 47                 16.0  180000.0                  0                        1
# 60                 23.0  170000.0                  1                        1
# 63                 21.0  180000.0                 10                        2
# 69                 18.0  150000.0                 11                        1
# 77                  6.0  100000.0                 20                        1

# %%
df_edited['Gender'] = df_edited['Gender'].astype('category')

# %%
df_edited['Gender Encoded'] = df_edited['Gender'].cat.codes
df_edited.head()
# Out:
#      Age  Gender Education Level                 Job Title  \
# 47  45.0  Female        Master's     Director of Marketing
# 60  51.0  Female        Master's    Director of Operations
# 63  47.0    Male             PhD     Senior Data Scientist
# 69  49.0  Female        Master's  Senior Financial Analyst
# 77  32.0    Male        Master's  Senior Software Engineer
#
#     Years of Experience    Salary  Job Title Encoded  Education Level Encoded  \
# 47                 16.0  180000.0                  0                        1
# 60                 23.0  170000.0                  1                        1
# 63                 21.0  180000.0                 10                        2
# 69                 18.0  150000.0                 11                        1
# 77                  6.0  100000.0                 20                        1
#
#     Gender Encoded
# 47               0
# 60               0
# 63               1
# 69               0
# 77               1

# %%
df_final = df_edited.drop(['Gender', 'Education Level', 'Job Title'], axis=1)
df_final.head()
# Out:
#      Age  Years of Experience    Salary  Job Title Encoded  \
# 47  45.0                 16.0  180000.0                  0
# 60  51.0                 23.0  170000.0                  1
# 63  47.0                 21.0  180000.0                 10
# 69  49.0                 18.0  150000.0                 11
# 77  32.0                  6.0  100000.0                 20
#
#     Education Level Encoded  Gender Encoded
# 47                        1               0
# 60                        1               0
# 63                        2               1
# 69                        1               0
# 77                        1               1

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147 entries, 47 to 374
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      147 non-null    float64
#  1   Years of Experience      147 non-null    float64
#  2   Salary                   147 non-null    float64
#  3   Job Title Encoded        147 non-null    int8
#  4   Education Level Encoded  147 non-null    int8
#  5   Gender Encoded           147 non-null    int8
# dtypes: float64(3), int8(3)
# memory usage: 5.0 KB

# %%
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = df_final.iloc[:,[0,1,3,4,5]]
y = df_final.iloc[:,2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.head()
# Out:
#       Age  Years of Experience  Job Title Encoded  Education Level Encoded  \
# 230  30.0                  3.0                  6                        0
# 254  35.0                  8.0                 13                        0
# 169  34.0                  9.0                 20                        1
# 327  32.0                  3.0                  5                        0
# 156  32.0                  5.0                  4                        0
#
#      Gender Encoded
# 230               1
# 254               0
# 169               1
# 327               1
# 156               0

# %%
y_train.head()
# Out:
# 230     45000.0
# 254     85000.0
# 169    105000.0
# 327     55000.0
# 156     50000.0
# Name: Salary, dtype: float64

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
err = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
y_pred, y_test
# Out:
# (array([174597.23298328, 145854.27396113,  45863.46408734,  98593.87685367,
#         112767.86243827, 147410.73102416,  64030.16417393,  48850.25083835,
#         123839.88809771, 167364.82848978, 106701.18019378,  45267.66496099,
#          49651.11427701, 145854.27396113, 157320.42001421,  66286.85830545,
#          96925.19072919,  46261.99002067, 167364.82848978, 130387.19629439,
#          87398.88690078, 141812.25910399,  91577.27190449, 117646.48451048,
#         152374.83869484, 129861.67552673,  85406.42520944, 172604.77129194,
#         154680.34072104, 129861.67552673]),
#  130    160000.0
#  374    150000.0
#  372     40000.0
#  352    110000.0
#  296    130000.0
#  146    150000.0
#  345     60000.0
#  171     40000.0
#  104     80000.0
#  226    160000.0
#  119    120000.0
#  292     40000.0
#  274     40000.0
#  338    150000.0
#  371    170000.0
#  238     70000.0
#  275    120000.0
#  195     40000.0
#  262    160000.0
#  108    100000.0
#  358     95000.0
#  173    140000.0
#  245     95000.0
#  308    120000.0
#  365    170000.0
#  315    130000.0
#  370     85000.0
#  246    180000.0
#  297    160000.0
#  288    130000.0
#  Name: Salary, dtype: float64)

# %%
err
# Out:
# np.float64(13266.593071385849)

# %%
print(pd.DataFrame(zip(X.columns, reg.coef_)))
print(reg.intercept_)
# Out:
#                          0            1
# 0                      Age  1694.562128
# 1      Years of Experience  4647.681756
# 2        Job Title Encoded   297.899563
# 3  Education Level Encoded  6927.307779
# 4           Gender Encoded  3880.485441
# -14957.39764739848
